# %%
import keras
from keras.models import Model
from keras.layers.core import Flatten, Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
#from keras.models import load_model
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
net = keras.applications.mobilenet_v2.MobileNetV2(include_top=False, weights='imagenet', input_tensor=None, input_shape=(224, 224, 3))
# Out:
# ...
# 9412608/9406464 [==============================] - 7s 1us/step

# %%
x = net.output
x = Flatten()(x)
x = Dense(128)(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(20, activation='softmax', name='softmax')(x)
net_final = Model(inputs=net.input, outputs=output_layer)

# %%
count=0
for layer in net_final.layers:
    count+=1
print(count)
# Out:
# 160

# %%
print(net_final.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
"""
# 設定凍結與要進行訓練的網路層
for layer in net_final.layers[:-5]:
    layer.trainable = False
for layer in net_final.layers[-5:]:
    layer.trainable = True
"""

# %%
for layer in net_final.layers:
    layer.trainable = True

# %%
net_final.compile(Adam(lr=.00002), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
V1 = np.load("C:/Users/cloudsuccesss0709/Desktop/numpydataKeras_20_val/imgonehot_val_1000.npy")
V2 = np.load("C:/Users/cloudsuccesss0709/Desktop/numpydataKeras_20_val/labelonehot_val_1000.npy")

# %%
for i in range(5):#訓練5週期
    for j in range(100):#100,000張分100批訓練
        X = np.load( "C:/Users/cloudsuccesss0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
        Y = np.load( "C:/Users/cloudsuccesss0709/Desktop/numpydataKeras/labelonehot_"+str((j+1)*1000)+".npy" )
        net_final.fit(x = X, y = Y,
                      epochs = 1,#訓練週期
                      validation_data=(V1, V2),
                      verbose = 1)
        print('Done training ', (j+1)*1000 ,' images in Epoch : ', i)
    print('Done training 100000 images, Epoch ', i ,'  -------------')
# Out:
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 34s 34ms/step - loss: 3.7584 - acc: 0.0590 - val_loss: 2.9641 - val_acc: 0.0990
# Done training  1000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 19s 19ms/step - loss: 3.0292 - acc: 0.0990 - val_loss: 2.8827 - val_acc: 0.1380
# Done training  2000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 19s 19ms/step - loss: 2.9141 - acc: 0.1040 - val_loss: 2.7954 - val_acc: 0.1680
# Done training  3000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.8745 - acc: 0.1140 - val_loss: 2.7244 - val_acc: 0.1700
# Done training  4000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# ...

# %%
# 將模型儲存至 HDF5 檔案中
net_final.save('C:/Users/cloudsuccesss0709/Desktop/transfer_learning_MobileNetV2_02.h5')
print('Saved Succeed--------------')
# Out:
# Saved Succeed--------------

# %% [markdown]
# # 計算top-1、top-3 accuracy

# %%
from keras.models import load_model
from time import time
import numpy as np
from keras.optimizers import Adam
import keras
import functools
# Out:
# Using TensorFlow backend.

# %%
#載入模型
model = load_model('C:/Users/cloudsuccesss0709/Desktop/transfer_learning_MobileNetV2_02.h5')

# %%
for layer in model.layers:
    layer.trainable = False

# %%
top3_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=3)

top3_acc.__name__ = 'top3_acc'

model.compile(Adam(lr=.00002122), loss='categorical_crossentropy', metrics = ['accuracy', top3_acc])

# %%
V1 = np.load("C:/Users/cloudsuccesss0709/Desktop/numpydataKeras_20_val/imgonehot_val_1000.npy")
V2 = np.load("C:/Users/cloudsuccesss0709/Desktop/numpydataKeras_20_val/labelonehot_val_1000.npy")

# %%
for i in range(5):#訓練5週期
    for j in range(100):#100,000張分100批訓練
        X = np.load( "C:/Users/cloudsuccesss0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
        Y = np.load( "C:/Users/cloudsuccesss0709/Desktop/numpydataKeras/labelonehot_"+str((j+1)*1000)+".npy" )
        model.fit(x = X, y = Y,
                      epochs = 1,#訓練週期
                      validation_data=(V1, V2),
                      verbose = 1)#顯示訓練過程，1为输出进度条记录，2为每个epoch输出一行记录
        print('Done training ', (j+1)*1000 ,' images in Epoch : ', i)
    print('Done training 100000 images, Epoch ', i ,'  -------------')
# Out:
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.8226 - acc: 0.7480 - top3_acc: 0.9240 - val_loss: 0.9828 - val_acc: 0.6780 - val_top3_acc: 0.9120
# Done training  1000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.8375 - acc: 0.7210 - top3_acc: 0.9220 - val_loss: 0.9828 - val_acc: 0.6780 - val_top3_acc: 0.9120
# Done training  2000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.8549 - acc: 0.7180 - top3_acc: 0.9180 - val_loss: 0.9828 - val_acc: 0.6780 - val_top3_acc: 0.9120
# Done training  3000  images in Epoch :  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
