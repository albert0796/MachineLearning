# %%
import keras
from keras.models import Model
from keras.layers.core import Flatten, Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
net = keras.applications.nasnet.NASNetMobile(include_top=False, weights='imagenet', input_tensor=None, input_shape=(224, 224, 3))

# %%
x = net.output
x = Flatten()(x)
x = Dense(128)(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(20, activation='softmax', name='softmax')(x)
net_final = Model(inputs=net.input, outputs=output_layer)

# %%
count=0
for layer in net_final.layers:
    count+=1
print(count)
# Out:
# 774

# %%
print(net_final.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 11) 352         activation_1[0][0]
# ...

# %%
# 設定凍結與要進行訓練的網路層
for layer in net_final.layers:
    layer.trainable = True

# %%
net_final.compile(Adam(lr=.00002), loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
V1 = np.load("C:/Users/cloudadavncenew0709/Desktop/numpydataKeras_20_val/imgonehot_val_1000.npy")
V2 = np.load("C:/Users/cloudadavncenew0709/Desktop/numpydataKeras_20_val/labelonehot_val_1000.npy")

# %%
for i in range(5):#訓練5週期
    for j in range(100):#100,000張分100批訓練
        X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
        Y = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/labelonehot_"+str((j+1)*1000)+".npy" )
        net_final.fit(x = X, y = Y,
                      epochs = 1,#訓練週期
                      validation_data=(V1, V2),
                      verbose = 1)#顯示訓練過程，1为输出进度条记录，2为每个epoch输出一行记录
        print('Done training ', (j+1)*1000 ,' images in Epoch : ', i)
    print('Done training 100000 images, Epoch ', i ,'  -------------')
# Out:
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 119s 119ms/step - loss: 3.5148 - acc: 0.0490 - val_loss: 2.9311 - val_acc: 0.1140
# Done training  1000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 34s 34ms/step - loss: 2.9990 - acc: 0.0780 - val_loss: 2.8239 - val_acc: 0.1430
# Done training  2000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 34s 34ms/step - loss: 2.9050 - acc: 0.1120 - val_loss: 2.7140 - val_acc: 0.2000
# Done training  3000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 34s 34ms/step - loss: 2.7241 - acc: 0.1600 - val_loss: 2.5052 - val_acc: 0.2750
# Done training  4000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# ...

# %%
net_final.save('C:/Users/cloudadavncenew0709/Desktop/transfer_learning_NASNetMobile_02.h5')
print('Saved Succeed--------------')
# Out:
# Saved Succeed--------------

# %% [markdown]
# # 計算top-1、top-3 accuracy

# %%
from keras.models import load_model
from time import time
import numpy as np
from keras.optimizers import Adam
import keras
import functools

# %%
model = load_model('C:/Users/cloudadavncenew0709/Desktop/transfer_learning_NASNetMobile_02.h5')

# %%
for layer in model.layers:
    layer.trainable = False

# %%
top3_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=3)

top3_acc.__name__ = 'top3_acc'

model.compile(Adam(lr=.00002), loss='categorical_crossentropy', metrics = ['accuracy', top3_acc])

# %%
V1 = np.load("C:/Users/cloudadavncenew0709/Desktop/numpydataKeras_20_val/imgonehot_val_1000.npy")
V2 = np.load("C:/Users/cloudadavncenew0709/Desktop/numpydataKeras_20_val/labelonehot_val_1000.npy")

# %%
for i in range(5):#訓練5週期
    for j in range(100):#100,000張分100批訓練
        X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
        Y = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/labelonehot_"+str((j+1)*1000)+".npy" )
        model.fit(x = X, y = Y,
                      epochs = 1,#訓練週期
                      validation_data=(V1, V2),
                      verbose = 1)#顯示訓練過程，1为输出进度条记录，2为每个epoch输出一行记录
        print('Done training ', (j+1)*1000 ,' images in Epoch : ', i)
    print('Done training 100000 images, Epoch ', i ,'  -------------')
# Out:
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 29s 29ms/step - loss: 0.7656 - acc: 0.7650 - top3_acc: 0.9320 - val_loss: 0.8591 - val_acc: 0.7320 - val_top3_acc: 0.9250s: 0.7397 - acc: 0.775
# Done training  1000  images in Epoch :  0
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 13s 13ms/step - loss: 0.7203 - acc: 0.7800 - top3_acc: 0.9480 - val_loss: 0.8591 - val_acc: 0.7320 - val_top3_acc: 0.9250
# Done training  2000  images in Epoch :  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3edc24ec02ec> in <module>
#       1 for i in range(5):#訓練5週期
#       2     for j in range(100):#100,000張分100批訓練
# ----> 3         X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
# ...
