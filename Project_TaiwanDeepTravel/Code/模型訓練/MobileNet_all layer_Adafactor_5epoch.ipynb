# %%
import keras
from keras.models import Model
from keras.layers.core import Flatten, Dense, Dropout, Activation
from keras.metrics import categorical_crossentropy
from keras.models import load_model
import pandas as pd
import numpy as np
from tensor2tensor.utils.adafactor import AdafactorOptimizer
import functools
# Out:
# Using TensorFlow backend.

# %%
net = keras.applications.mobilenet.MobileNet(include_top=False, weights='imagenet', input_tensor=None, input_shape=(224, 224, 3))

# %%
x = net.output
x = Flatten()(x)
x = Dense(128)(x)
x = Activation('relu')(x)
x = Dropout(0.2)(x)
output_layer = Dense(20, activation='softmax', name='softmax')(x)
net_final = Model(inputs=net.input, outputs=output_layer)

# %%
count=0
for layer in net_final.layers:
    count+=1
print(count)
# Out:
# 92

# %%
print(net_final.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               6422656
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# softmax (Dense)              (None, 20)                2580
# =================================================================
# Total params: 9,654,100
# Trainable params: 9,632,212
# Non-trainable params: 21,888
# _________________________________________________________________
# None

# %%
for layer in net_final.layers:
    layer.trainable = True

# %%
optimizerAdafactor = AdafactorOptimizer(learning_rate=None,
                                        multiply_by_parameter_scale=True,
                                        decay_rate=None,
                                        factored=True,
                                        simulated_quantize_bits=None, 
                                        use_locking=False)

# %%
net_final.compile(optimizer = optimizerAdafactor, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
V1 = np.load("C:/Users/cloudadavncenew0709/Desktop/numpydataKeras_20_new_val/imgonehot_new_val_2000.npy")
V2 = np.load("C:/Users/cloudadavncenew0709/Desktop/numpydataKeras_20_new_val/labelonehot_new_val_2000.npy")

# %%
weights_file = 'C:/Users/cloudadavncenew0709/Desktop/MobileNet_Adafactor_SaveBest_02.h5'
#early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='auto', verbose=2)
model_checkpoint = ModelCheckpoint(weights_file, monitor='val_loss', save_best_only=True, verbose=2)
callbacks = [model_checkpoint]

# %%
output = []

# %%
for i in range(5):#訓練5週期
    for j in range(100):#100,000張分100批訓練
        X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
        Y = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/labelonehot_"+str((j+1)*1000)+".npy" )
        net_final.fit(x = X, y = Y,
                      epochs = 1,#訓練週期
                      validation_data=(V1, V2),
                      callbacks = callbacks,
                      verbose = 1)#顯示訓練過程，1为输出进度条记录，2为每个epoch输出一行记录
        loss = net_final.history.history['loss'][0]
        acc = net_final.history.history['acc'][0]
        val_loss = net_final.history.history['val_loss'][0]
        val_acc = net_final.history.history['val_acc'][0]
        epoch = float(i) + (float(j+1)/100.00)
        output.append([loss, acc, val_loss, val_acc, epoch])
        print(output[-1])
        print('Done training ', (j+1)*1000 ,' images in Epoch : ', i)
    print('Done training 100000 images, Epoch ', i ,'  -------------')
output_df = pd.DataFrame(output, columns=['loss', 'acc', 'val_loss', 'val_acc', 'epoch'])
output_df.to_csv("C:/Users/cloudadavncenew0709/Desktop/MobileNet_Adafactor_SaveBest_data.csv")
# Out:
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 29s 29ms/step - loss: 3.6202 - acc: 0.0950 - val_loss: 3.1730 - val_acc: 0.0985
# Done training  1000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9921 - acc: 0.1400 - val_loss: 3.0497 - val_acc: 0.1015
# Done training  2000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9078 - acc: 0.1600 - val_loss: 3.4064 - val_acc: 0.1030
# Done training  3000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.8019 - acc: 0.1750 - val_loss: 3.2217 - val_acc: 0.0995
# Done training  4000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.8058 - acc: 0.1770 - val_loss: 3.2035 - val_acc: 0.1465
# Done training  5000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.7839 - acc: 0.1690 - val_loss: 3.3230 - val_acc: 0.1600
# Done training  6000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6674 - acc: 0.2240 - val_loss: 3.9589 - val_acc: 0.1145
# Done training  7000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.7559 - acc: 0.1920 - val_loss: 12.2612 - val_acc: 0.0545
# Done training  8000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6376 - acc: 0.2100 - val_loss: 6.0583 - val_acc: 0.1035
# Done training  9000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6963 - acc: 0.2030 - val_loss: 7.4992 - val_acc: 0.1060
# Done training  10000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6654 - acc: 0.2220 - val_loss: 8.3119 - val_acc: 0.1045
# Done training  11000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.5828 - acc: 0.2000 - val_loss: 8.1997 - val_acc: 0.1095
# Done training  12000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4154 - acc: 0.2740 - val_loss: 8.1033 - val_acc: 0.1390
# Done training  13000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.5830 - acc: 0.2460 - val_loss: 12.8235 - val_acc: 0.0575
# Done training  14000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4726 - acc: 0.2530 - val_loss: 14.6798 - val_acc: 0.0565
# Done training  15000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.4412 - acc: 0.2460 - val_loss: 7.8185 - val_acc: 0.1070
# Done training  16000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4708 - acc: 0.2730 - val_loss: 6.8775 - val_acc: 0.1490
# Done training  17000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.3796 - acc: 0.2960 - val_loss: 9.6011 - val_acc: 0.1040
# Done training  18000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.3733 - acc: 0.2800 - val_loss: 4.3769 - val_acc: 0.1490
# Done training  19000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.3769 - acc: 0.2960 - val_loss: 5.9773 - val_acc: 0.1460
# Done training  20000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4605 - acc: 0.2960 - val_loss: 13.1857 - val_acc: 0.0865
# Done training  21000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.3995 - acc: 0.2890 - val_loss: 9.1398 - val_acc: 0.1115
# Done training  22000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.3785 - acc: 0.2740 - val_loss: 8.1013 - val_acc: 0.1185
# Done training  23000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.3275 - acc: 0.2920 - val_loss: 5.5076 - val_acc: 0.1655
# Done training  24000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4017 - acc: 0.2800 - val_loss: 5.2300 - val_acc: 0.1585
# Done training  25000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4665 - acc: 0.2950 - val_loss: 5.4626 - val_acc: 0.1615
# Done training  26000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4148 - acc: 0.2950 - val_loss: 7.2545 - val_acc: 0.1405
# Done training  27000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4757 - acc: 0.2820 - val_loss: 6.6706 - val_acc: 0.1720
# Done training  28000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4162 - acc: 0.3000 - val_loss: 5.3614 - val_acc: 0.1665
# Done training  29000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4606 - acc: 0.2690 - val_loss: 11.4917 - val_acc: 0.1020
# Done training  30000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4597 - acc: 0.3000 - val_loss: 11.4474 - val_acc: 0.1160
# Done training  31000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6143 - acc: 0.2770 - val_loss: 10.6456 - val_acc: 0.1090
# Done training  32000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5098 - acc: 0.2820 - val_loss: 8.8848 - val_acc: 0.1515
# Done training  33000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6336 - acc: 0.2800 - val_loss: 6.2075 - val_acc: 0.1445
# Done training  34000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5094 - acc: 0.2730 - val_loss: 6.3753 - val_acc: 0.2100
# Done training  35000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4304 - acc: 0.2730 - val_loss: 5.6908 - val_acc: 0.1910
# Done training  36000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.5004 - acc: 0.2810 - val_loss: 10.3836 - val_acc: 0.1070
# Done training  37000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.5740 - acc: 0.2550 - val_loss: 14.1178 - val_acc: 0.0635
# Done training  38000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5288 - acc: 0.2500 - val_loss: 11.4352 - val_acc: 0.1315
# Done training  39000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.4634 - acc: 0.2830 - val_loss: 10.2538 - val_acc: 0.1635
# Done training  40000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4135 - acc: 0.3160 - val_loss: 8.2740 - val_acc: 0.1335
# Done training  41000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4201 - acc: 0.2920 - val_loss: 10.3703 - val_acc: 0.1175
# Done training  42000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6324 - acc: 0.2800 - val_loss: 7.2791 - val_acc: 0.1100
# Done training  43000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4148 - acc: 0.2790 - val_loss: 6.4491 - val_acc: 0.1540
# Done training  44000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5991 - acc: 0.3120 - val_loss: 5.4082 - val_acc: 0.0960
# Done training  45000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.4536 - acc: 0.2930 - val_loss: 3.5285 - val_acc: 0.1435
# Done training  46000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4573 - acc: 0.2940 - val_loss: 4.6779 - val_acc: 0.1465
# Done training  47000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.3845 - acc: 0.2850 - val_loss: 3.3731 - val_acc: 0.1375
# Done training  48000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6282 - acc: 0.2670 - val_loss: 6.2285 - val_acc: 0.1625
# Done training  49000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5492 - acc: 0.2880 - val_loss: 12.8266 - val_acc: 0.0765
# Done training  50000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5038 - acc: 0.2830 - val_loss: 14.3813 - val_acc: 0.0645
# Done training  51000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7382 - acc: 0.2920 - val_loss: 8.2311 - val_acc: 0.1345
# Done training  52000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6716 - acc: 0.2770 - val_loss: 6.6231 - val_acc: 0.1250
# Done training  53000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.5152 - acc: 0.3100 - val_loss: 4.3569 - val_acc: 0.1430
# Done training  54000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7379 - acc: 0.2890 - val_loss: 6.6684 - val_acc: 0.1550
# Done training  55000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6161 - acc: 0.2890 - val_loss: 10.0783 - val_acc: 0.1660
# Done training  56000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6628 - acc: 0.2540 - val_loss: 4.7969 - val_acc: 0.1985
# Done training  57000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5458 - acc: 0.2730 - val_loss: 13.3683 - val_acc: 0.0730
# Done training  58000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6810 - acc: 0.2890 - val_loss: 4.1627 - val_acc: 0.1420
# Done training  59000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5075 - acc: 0.2600 - val_loss: 3.4531 - val_acc: 0.2010
# Done training  60000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4320 - acc: 0.2590 - val_loss: 8.0098 - val_acc: 0.1300
# Done training  61000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4441 - acc: 0.2570 - val_loss: 13.8295 - val_acc: 0.0610
# Done training  62000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7779 - acc: 0.2860 - val_loss: 12.8359 - val_acc: 0.0800
# Done training  63000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6282 - acc: 0.2690 - val_loss: 2.8031 - val_acc: 0.1310
# Done training  64000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5769 - acc: 0.2550 - val_loss: 2.9759 - val_acc: 0.1455
# Done training  65000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7126 - acc: 0.2740 - val_loss: 3.4464 - val_acc: 0.1600
# Done training  66000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5016 - acc: 0.2780 - val_loss: 4.9184 - val_acc: 0.1090
# Done training  67000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5107 - acc: 0.2620 - val_loss: 4.3354 - val_acc: 0.0615
# Done training  68000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8060 - acc: 0.2700 - val_loss: 6.3880 - val_acc: 0.1595
# Done training  69000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8097 - acc: 0.2770 - val_loss: 4.4474 - val_acc: 0.1205
# Done training  70000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5300 - acc: 0.2820 - val_loss: 2.9146 - val_acc: 0.1510
# Done training  71000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6501 - acc: 0.2490 - val_loss: 3.1990 - val_acc: 0.2000
# Done training  72000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7136 - acc: 0.2560 - val_loss: 3.7222 - val_acc: 0.1860
# Done training  73000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6447 - acc: 0.2400 - val_loss: 3.1917 - val_acc: 0.1750
# Done training  74000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5594 - acc: 0.2700 - val_loss: 3.0042 - val_acc: 0.2295
# Done training  75000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.6289 - acc: 0.2360 - val_loss: 5.0526 - val_acc: 0.1375
# Done training  76000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6262 - acc: 0.2930 - val_loss: 3.2744 - val_acc: 0.1545
# Done training  77000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7599 - acc: 0.2870 - val_loss: 2.9188 - val_acc: 0.1275
# Done training  78000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7303 - acc: 0.2870 - val_loss: 5.5538 - val_acc: 0.1060
# Done training  79000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6511 - acc: 0.2840 - val_loss: 3.7223 - val_acc: 0.2045
# Done training  80000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7142 - acc: 0.2720 - val_loss: 4.5422 - val_acc: 0.1740
# Done training  81000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7910 - acc: 0.2280 - val_loss: 3.7040 - val_acc: 0.1170
# Done training  82000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.4829 - acc: 0.2730 - val_loss: 3.4304 - val_acc: 0.2275
# Done training  83000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7280 - acc: 0.2510 - val_loss: 3.0211 - val_acc: 0.1970
# Done training  84000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7050 - acc: 0.2450 - val_loss: 3.5436 - val_acc: 0.1310
# Done training  85000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7183 - acc: 0.2520 - val_loss: 4.5434 - val_acc: 0.1495
# Done training  86000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6569 - acc: 0.2540 - val_loss: 4.0936 - val_acc: 0.1465
# Done training  87000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6507 - acc: 0.2310 - val_loss: 4.5283 - val_acc: 0.1410
# Done training  88000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7176 - acc: 0.2340 - val_loss: 3.2952 - val_acc: 0.1595
# Done training  89000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.5827 - acc: 0.2550 - val_loss: 3.5119 - val_acc: 0.1450
# Done training  90000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7364 - acc: 0.2380 - val_loss: 4.1274 - val_acc: 0.1915
# Done training  91000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1639 - acc: 0.2680 - val_loss: 3.4877 - val_acc: 0.1475
# Done training  92000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7202 - acc: 0.2410 - val_loss: 6.0279 - val_acc: 0.0650
# Done training  93000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7693 - acc: 0.1920 - val_loss: 3.2415 - val_acc: 0.1145
# Done training  94000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6272 - acc: 0.2390 - val_loss: 6.0567 - val_acc: 0.1035
# Done training  95000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7593 - acc: 0.2400 - val_loss: 8.3662 - val_acc: 0.1005
# Done training  96000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0553 - acc: 0.2150 - val_loss: 5.5950 - val_acc: 0.1355
# Done training  97000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8032 - acc: 0.2130 - val_loss: 4.0803 - val_acc: 0.1535
# Done training  98000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6803 - acc: 0.2260 - val_loss: 2.8763 - val_acc: 0.1920
# Done training  99000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9553 - acc: 0.2100 - val_loss: 3.2161 - val_acc: 0.1625
# Done training  100000  images in Epoch :  0
# Done training 100000 images, Epoch  0   -------------
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8509 - acc: 0.2270 - val_loss: 4.1494 - val_acc: 0.1545
# Done training  1000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8975 - acc: 0.2120 - val_loss: 3.1655 - val_acc: 0.1400
# Done training  2000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8749 - acc: 0.2380 - val_loss: 10.2551 - val_acc: 0.0750
# Done training  3000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8213 - acc: 0.2260 - val_loss: 8.1372 - val_acc: 0.1040
# Done training  4000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0811 - acc: 0.2160 - val_loss: 4.6256 - val_acc: 0.1100
# Done training  5000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8014 - acc: 0.2150 - val_loss: 6.3948 - val_acc: 0.1430
# Done training  6000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6942 - acc: 0.2230 - val_loss: 6.1549 - val_acc: 0.1495
# Done training  7000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8584 - acc: 0.2140 - val_loss: 6.3117 - val_acc: 0.1180
# Done training  8000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9330 - acc: 0.2260 - val_loss: 3.3288 - val_acc: 0.1125
# Done training  9000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0364 - acc: 0.2270 - val_loss: 2.8301 - val_acc: 0.1310
# Done training  10000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.7675 - acc: 0.2190 - val_loss: 3.2546 - val_acc: 0.1650
# Done training  11000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9639 - acc: 0.2120 - val_loss: 2.7791 - val_acc: 0.1685
# Done training  12000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9450 - acc: 0.2260 - val_loss: 3.0174 - val_acc: 0.0815
# Done training  13000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6987 - acc: 0.2080 - val_loss: 3.0705 - val_acc: 0.1840
# Done training  14000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.6924 - acc: 0.2450 - val_loss: 3.1613 - val_acc: 0.1735
# Done training  15000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.7092 - acc: 0.1820 - val_loss: 5.1629 - val_acc: 0.1060
# Done training  16000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9514 - acc: 0.2200 - val_loss: 5.9681 - val_acc: 0.1435
# Done training  17000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.7718 - acc: 0.2170 - val_loss: 5.3993 - val_acc: 0.1605
# Done training  18000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8189 - acc: 0.2050 - val_loss: 4.2010 - val_acc: 0.1305
# Done training  19000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9877 - acc: 0.2150 - val_loss: 8.1937 - val_acc: 0.1150
# Done training  20000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8871 - acc: 0.1810 - val_loss: 3.7407 - val_acc: 0.1265
# Done training  21000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8317 - acc: 0.1820 - val_loss: 8.4719 - val_acc: 0.0655
# Done training  22000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8262 - acc: 0.1890 - val_loss: 6.2628 - val_acc: 0.0910
# Done training  23000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8065 - acc: 0.1820 - val_loss: 2.9018 - val_acc: 0.1110
# Done training  24000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.8507 - acc: 0.1660 - val_loss: 7.5700 - val_acc: 0.0640
# Done training  25000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9767 - acc: 0.1680 - val_loss: 6.7309 - val_acc: 0.0925
# Done training  26000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9932 - acc: 0.1610 - val_loss: 2.8881 - val_acc: 0.1130
# Done training  27000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0065 - acc: 0.1520 - val_loss: 3.1078 - val_acc: 0.0655
# Done training  28000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0736 - acc: 0.1280 - val_loss: 3.0098 - val_acc: 0.0985
# Done training  29000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9462 - acc: 0.1130 - val_loss: 3.2545 - val_acc: 0.1345
# Done training  30000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1924 - acc: 0.1060 - val_loss: 2.9587 - val_acc: 0.0995
# Done training  31000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9437 - acc: 0.0910 - val_loss: 10.2589 - val_acc: 0.0565
# Done training  32000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1963 - acc: 0.1110 - val_loss: 3.4525 - val_acc: 0.1220
# Done training  33000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9768 - acc: 0.0980 - val_loss: 4.1205 - val_acc: 0.0685
# Done training  34000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0860 - acc: 0.0650 - val_loss: 3.0213 - val_acc: 0.0815
# Done training  35000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9893 - acc: 0.0840 - val_loss: 2.8673 - val_acc: 0.0985
# Done training  36000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0942 - acc: 0.0780 - val_loss: 2.9782 - val_acc: 0.0645
# Done training  37000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1500 - acc: 0.0700 - val_loss: 2.9649 - val_acc: 0.0695
# Done training  38000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0566 - acc: 0.0670 - val_loss: 3.0556 - val_acc: 0.0615
# Done training  39000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1547 - acc: 0.0690 - val_loss: 3.0255 - val_acc: 0.0540
# Done training  40000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2686 - acc: 0.0800 - val_loss: 2.9650 - val_acc: 0.0650
# Done training  41000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0373 - acc: 0.0770 - val_loss: 3.0101 - val_acc: 0.0500
# Done training  42000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0067 - acc: 0.0660 - val_loss: 3.0405 - val_acc: 0.0580
# Done training  43000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0730 - acc: 0.0840 - val_loss: 2.9996 - val_acc: 0.0540
# Done training  44000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0504 - acc: 0.0620 - val_loss: 5.7054 - val_acc: 0.0560
# Done training  45000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0231 - acc: 0.0610 - val_loss: 3.0158 - val_acc: 0.0510
# Done training  46000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0014 - acc: 0.0380 - val_loss: 3.0419 - val_acc: 0.0730
# Done training  47000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0168 - acc: 0.0520 - val_loss: 3.5897 - val_acc: 0.0905
# Done training  48000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0962 - acc: 0.0650 - val_loss: 2.9716 - val_acc: 0.0830
# Done training  49000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0803 - acc: 0.0670 - val_loss: 3.0109 - val_acc: 0.0505
# Done training  50000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1148 - acc: 0.0590 - val_loss: 2.9988 - val_acc: 0.0550
# Done training  51000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0063 - acc: 0.0460 - val_loss: 3.0035 - val_acc: 0.0500
# Done training  52000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0031 - acc: 0.0440 - val_loss: 3.0041 - val_acc: 0.0500
# Done training  53000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9978 - acc: 0.0510 - val_loss: 3.0042 - val_acc: 0.0500
# Done training  54000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0107 - acc: 0.0580 - val_loss: 2.8804 - val_acc: 0.0845
# Done training  55000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0504 - acc: 0.0660 - val_loss: 2.9707 - val_acc: 0.0600
# Done training  56000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0013 - acc: 0.0630 - val_loss: 3.0041 - val_acc: 0.0500
# Done training  57000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0004 - acc: 0.0550 - val_loss: 3.0043 - val_acc: 0.0500
# Done training  58000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0072 - acc: 0.0520 - val_loss: 3.0038 - val_acc: 0.0500
# Done training  59000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0052 - acc: 0.0400 - val_loss: 3.0036 - val_acc: 0.0500
# Done training  60000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0061 - acc: 0.0490 - val_loss: 3.0036 - val_acc: 0.0500
# Done training  61000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0068 - acc: 0.0510 - val_loss: 3.0036 - val_acc: 0.0500
# Done training  62000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0070 - acc: 0.0460 - val_loss: 3.0032 - val_acc: 0.0500
# Done training  63000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0068 - acc: 0.0470 - val_loss: 3.0031 - val_acc: 0.0500
# Done training  64000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0025 - acc: 0.0620 - val_loss: 3.0035 - val_acc: 0.0500
# Done training  65000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0063 - acc: 0.0520 - val_loss: 3.0033 - val_acc: 0.0500
# Done training  66000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0062 - acc: 0.0550 - val_loss: 3.0031 - val_acc: 0.0500
# Done training  67000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0093 - acc: 0.0450 - val_loss: 3.0027 - val_acc: 0.0500
# Done training  68000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0000 - acc: 0.0640 - val_loss: 3.0031 - val_acc: 0.0500
# Done training  69000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9991 - acc: 0.0550 - val_loss: 3.0032 - val_acc: 0.0500
# Done training  70000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0001 - acc: 0.0390 - val_loss: 3.0036 - val_acc: 0.0500
# Done training  71000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0012 - acc: 0.0520 - val_loss: 3.0037 - val_acc: 0.0500
# Done training  72000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0040 - acc: 0.0560 - val_loss: 3.0033 - val_acc: 0.0500
# Done training  73000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0077 - acc: 0.0460 - val_loss: 3.0032 - val_acc: 0.0500
# Done training  74000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9984 - acc: 0.0490 - val_loss: 3.0035 - val_acc: 0.0500
# Done training  75000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0009 - acc: 0.0570 - val_loss: 3.0039 - val_acc: 0.0500
# Done training  76000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0097 - acc: 0.0430 - val_loss: 3.0033 - val_acc: 0.0500
# Done training  77000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0082 - acc: 0.0470 - val_loss: 3.0032 - val_acc: 0.0500
# Done training  78000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0019 - acc: 0.0580 - val_loss: 3.0031 - val_acc: 0.0500
# Done training  79000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9997 - acc: 0.0540 - val_loss: 3.0037 - val_acc: 0.0500
# Done training  80000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0010 - acc: 0.0470 - val_loss: 3.0039 - val_acc: 0.0500
# Done training  81000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0031 - acc: 0.0580 - val_loss: 3.0038 - val_acc: 0.0500
# Done training  82000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0073 - acc: 0.0530 - val_loss: 3.0035 - val_acc: 0.0500
# Done training  83000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0039 - acc: 0.0430 - val_loss: 3.0038 - val_acc: 0.0500
# Done training  84000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0049 - acc: 0.0520 - val_loss: 3.0036 - val_acc: 0.0500
# Done training  85000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0025 - acc: 0.0360 - val_loss: 3.0033 - val_acc: 0.0500
# Done training  86000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0053 - acc: 0.0580 - val_loss: 3.0034 - val_acc: 0.0500
# Done training  87000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2.9979 - acc: 0.0490 - val_loss: 3.0041 - val_acc: 0.0500
# Done training  88000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0084 - acc: 0.0450 - val_loss: 3.0037 - val_acc: 0.0500
# Done training  89000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0026 - acc: 0.0390 - val_loss: 3.0035 - val_acc: 0.0500
# Done training  90000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0080 - acc: 0.0430 - val_loss: 3.0036 - val_acc: 0.0500
# Done training  91000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0029 - acc: 0.0520 - val_loss: 3.0038 - val_acc: 0.0500
# Done training  92000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0024 - acc: 0.0510 - val_loss: 3.0039 - val_acc: 0.0500
# Done training  93000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 2.9977 - acc: 0.0520 - val_loss: 3.0051 - val_acc: 0.0500
# Done training  94000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0030 - acc: 0.0480 - val_loss: 3.0054 - val_acc: 0.0500
# Done training  95000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0077 - acc: 0.0550 - val_loss: 3.0056 - val_acc: 0.0500
# Done training  96000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0047 - acc: 0.0480 - val_loss: 3.0051 - val_acc: 0.0500
# Done training  97000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0049 - acc: 0.0410 - val_loss: 3.0052 - val_acc: 0.0500
# Done training  98000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0026 - acc: 0.0500 - val_loss: 3.0055 - val_acc: 0.0500
# Done training  99000  images in Epoch :  1
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0029 - acc: 0.0410 - val_loss: 3.0052 - val_acc: 0.0500
# Done training  100000  images in Epoch :  1
# Done training 100000 images, Epoch  1   -------------
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0085 - acc: 0.0550 - val_loss: 3.0053 - val_acc: 0.0500
# Done training  1000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0100 - acc: 0.0400 - val_loss: 3.0050 - val_acc: 0.0500
# Done training  2000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0053 - acc: 0.0530 - val_loss: 3.0054 - val_acc: 0.0500
# Done training  3000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0019 - acc: 0.0520 - val_loss: 3.0057 - val_acc: 0.0500
# Done training  4000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0109 - acc: 0.0480 - val_loss: 3.0050 - val_acc: 0.0500
# Done training  5000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0111 - acc: 0.0530 - val_loss: 3.0044 - val_acc: 0.0500
# Done training  6000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0066 - acc: 0.0470 - val_loss: 3.0038 - val_acc: 0.0500
# Done training  7000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0011 - acc: 0.0480 - val_loss: 3.0041 - val_acc: 0.0500
# Done training  8000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0099 - acc: 0.0500 - val_loss: 3.0041 - val_acc: 0.0500
# Done training  9000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.0043 - acc: 0.0630 - val_loss: 3.0046 - val_acc: 0.0500
# Done training  10000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0057 - acc: 0.0510 - val_loss: 3.0046 - val_acc: 0.0500
# Done training  11000  images in Epoch :  2
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.0122 - acc: 0.0470 - val_loss: 3.0038 - val_acc: 0.0500
# ...
# Done training  30000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1350 - acc: 0.0470 - val_loss: 3.2067 - val_acc: 0.0500
# Done training  31000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1504 - acc: 0.0510 - val_loss: 3.1627 - val_acc: 0.0500
# Done training  32000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1520 - acc: 0.0450 - val_loss: 3.2394 - val_acc: 0.0500
# Done training  33000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1966 - acc: 0.0350 - val_loss: 3.2473 - val_acc: 0.0500
# Done training  34000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1429 - acc: 0.0650 - val_loss: 3.2271 - val_acc: 0.0500
# Done training  35000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1448 - acc: 0.0540 - val_loss: 3.2200 - val_acc: 0.0500
# Done training  36000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1635 - acc: 0.0460 - val_loss: 3.3025 - val_acc: 0.0500
# Done training  37000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1603 - acc: 0.0560 - val_loss: 3.3031 - val_acc: 0.0500
# Done training  38000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1839 - acc: 0.0480 - val_loss: 3.3454 - val_acc: 0.0500
# Done training  39000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1510 - acc: 0.0480 - val_loss: 3.3229 - val_acc: 0.0500
# Done training  40000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1720 - acc: 0.0590 - val_loss: 3.2826 - val_acc: 0.0500
# Done training  41000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1491 - acc: 0.0560 - val_loss: 3.2338 - val_acc: 0.0500
# Done training  42000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1473 - acc: 0.0520 - val_loss: 3.3437 - val_acc: 0.0500
# Done training  43000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1685 - acc: 0.0510 - val_loss: 3.1588 - val_acc: 0.0500
# Done training  44000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1579 - acc: 0.0540 - val_loss: 3.3688 - val_acc: 0.0500
# Done training  45000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1740 - acc: 0.0530 - val_loss: 3.2795 - val_acc: 0.0500
# Done training  46000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1714 - acc: 0.0600 - val_loss: 3.3981 - val_acc: 0.0500
# Done training  47000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2054 - acc: 0.0410 - val_loss: 3.2489 - val_acc: 0.0500
# Done training  48000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1820 - acc: 0.0560 - val_loss: 3.4230 - val_acc: 0.0500
# Done training  49000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1873 - acc: 0.0450 - val_loss: 3.2778 - val_acc: 0.0500
# Done training  50000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2048 - acc: 0.0420 - val_loss: 3.2768 - val_acc: 0.0500
# Done training  51000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1877 - acc: 0.0440 - val_loss: 3.3178 - val_acc: 0.0500
# Done training  52000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1910 - acc: 0.0480 - val_loss: 3.1505 - val_acc: 0.0500
# Done training  53000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1810 - acc: 0.0570 - val_loss: 3.2425 - val_acc: 0.0500
# Done training  54000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1644 - acc: 0.0590 - val_loss: 3.4271 - val_acc: 0.0500
# Done training  55000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1850 - acc: 0.0470 - val_loss: 3.2923 - val_acc: 0.0500
# Done training  56000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2056 - acc: 0.0500 - val_loss: 3.3957 - val_acc: 0.0500
# Done training  57000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1805 - acc: 0.0490 - val_loss: 3.4069 - val_acc: 0.0500
# Done training  58000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1829 - acc: 0.0570 - val_loss: 3.3689 - val_acc: 0.0500
# Done training  59000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2396 - acc: 0.0450 - val_loss: 3.3047 - val_acc: 0.0500
# Done training  60000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1987 - acc: 0.0390 - val_loss: 3.4147 - val_acc: 0.0500
# Done training  61000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.3659 - acc: 0.0510 - val_loss: 3.4047 - val_acc: 0.0500
# Done training  62000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1892 - acc: 0.0530 - val_loss: 3.4690 - val_acc: 0.0500
# Done training  63000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1945 - acc: 0.0550 - val_loss: 3.4959 - val_acc: 0.0500
# Done training  64000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1922 - acc: 0.0530 - val_loss: 3.3739 - val_acc: 0.0500
# Done training  65000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1928 - acc: 0.0470 - val_loss: 3.4591 - val_acc: 0.0500
# Done training  66000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2006 - acc: 0.0590 - val_loss: 3.3733 - val_acc: 0.0500
# Done training  67000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1827 - acc: 0.0460 - val_loss: 3.3303 - val_acc: 0.0500
# Done training  68000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2238 - acc: 0.0550 - val_loss: 3.3825 - val_acc: 0.0500
# Done training  69000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2157 - acc: 0.0480 - val_loss: 3.2843 - val_acc: 0.0500
# Done training  70000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1790 - acc: 0.0690 - val_loss: 3.5346 - val_acc: 0.0500
# Done training  71000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2285 - acc: 0.0430 - val_loss: 3.2894 - val_acc: 0.0500
# Done training  72000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2164 - acc: 0.0350 - val_loss: 3.2601 - val_acc: 0.0500
# Done training  73000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1975 - acc: 0.0610 - val_loss: 3.2271 - val_acc: 0.0500
# Done training  74000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2315 - acc: 0.0440 - val_loss: 3.2782 - val_acc: 0.0500
# Done training  75000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.1908 - acc: 0.0450 - val_loss: 3.4337 - val_acc: 0.0500
# Done training  76000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2167 - acc: 0.0580 - val_loss: 3.2971 - val_acc: 0.0500
# Done training  77000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2160 - acc: 0.0460 - val_loss: 3.5364 - val_acc: 0.0500
# Done training  78000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2122 - acc: 0.0550 - val_loss: 3.2455 - val_acc: 0.0500
# Done training  79000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1990 - acc: 0.0520 - val_loss: 3.3666 - val_acc: 0.0500
# Done training  80000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2311 - acc: 0.0510 - val_loss: 3.6043 - val_acc: 0.0500
# Done training  81000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2535 - acc: 0.0420 - val_loss: 3.5114 - val_acc: 0.0500
# Done training  82000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2155 - acc: 0.0610 - val_loss: 3.3444 - val_acc: 0.0500
# Done training  83000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2326 - acc: 0.0480 - val_loss: 3.2830 - val_acc: 0.0500
# Done training  84000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1871 - acc: 0.0600 - val_loss: 3.3333 - val_acc: 0.0500
# Done training  85000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.1954 - acc: 0.0460 - val_loss: 3.3553 - val_acc: 0.0500
# Done training  86000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2548 - acc: 0.0340 - val_loss: 3.4114 - val_acc: 0.0500
# Done training  87000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3.2386 - acc: 0.0450 - val_loss: 3.4235 - val_acc: 0.0500
# Done training  88000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2448 - acc: 0.0450 - val_loss: 3.3180 - val_acc: 0.0500
# Done training  89000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2207 - acc: 0.0470 - val_loss: 3.4667 - val_acc: 0.0500
# Done training  90000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2271 - acc: 0.0560 - val_loss: 3.3204 - val_acc: 0.0500
# Done training  91000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2211 - acc: 0.0480 - val_loss: 3.3994 - val_acc: 0.0500
# Done training  92000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2038 - acc: 0.0510 - val_loss: 3.4637 - val_acc: 0.0500
# Done training  93000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2459 - acc: 0.0500 - val_loss: 3.4243 - val_acc: 0.0500
# Done training  94000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2172 - acc: 0.0630 - val_loss: 3.3558 - val_acc: 0.0500
# Done training  95000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2119 - acc: 0.0600 - val_loss: 3.3380 - val_acc: 0.0500
# Done training  96000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2320 - acc: 0.0490 - val_loss: 3.4096 - val_acc: 0.0500
# Done training  97000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2458 - acc: 0.0420 - val_loss: 3.5687 - val_acc: 0.0500
# Done training  98000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2680 - acc: 0.0520 - val_loss: 3.4126 - val_acc: 0.0500
# Done training  99000  images in Epoch :  4
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2468 - acc: 0.0450 - val_loss: 3.5470 - val_acc: 0.0500
# Done training  100000  images in Epoch :  4
# Done training 100000 images, Epoch  4   -------------

# %%
# 將模型儲存至 HDF5 檔案中
net_final.save('C:/Users/cloudadavncenew0709/Desktop/MobileNet_Adafactor_02.h5')
print('Saved Succeed--------------')
# Out:
# Saved Succeed--------------
# C:\Users\cloudadavncenew0709\Anaconda3\envs\keras35\lib\site-packages\keras\engine\saving.py:118: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '

# %% [markdown]
# # 計算top-1、top-3 accuracy

# %%
for layer in net_final.layers:
    layer.trainable = True

# %%
top3_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=3)

top3_acc.__name__ = 'top3_acc'

net_final.compile(optimizer = optimizerAdafactor, loss='categorical_crossentropy', metrics = ['accuracy', top3_acc])

# %%
for i in range(2):#訓練5週期
    X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((i+1)*1000)+".npy" )
    Y = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/labelonehot_"+str((i+1)*1000)+".npy" )
    net_final.fit(x = X, y = Y,
                    epochs = 1,
                    validation_data=(V1, V2),
                    verbose = 1)
# Out:
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 29s 29ms/step - loss: 3.2579 - acc: 0.0510 - top3_acc: 0.1300 - val_loss: 3.4619 - val_acc: 0.0500 - val_top3_acc: 0.1500
# Done training  1000  images in Epoch :  0
# Train on 1000 samples, validate on 2000 samples
# Epoch 1/1
# 1000/1000 [==============================] - 21s 21ms/step - loss: 3.2134 - acc: 0.0530 - top3_acc: 0.1600 - val_loss: 3.3946 - val_acc: 0.0500 - val_top3_acc: 0.1500
# Done training  2000  images in Epoch :  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f71a9d2191f3> in <module>
#       1 for i in range(5):#訓練5週期
#       2     for j in range(100):#100,000張分100批訓練
# ----> 3         X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((j+1)*1000)+".npy" )
#       4         Y = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/labelonehot_"+str((j+1)*1000)+".npy" )
#       5         net_final.fit(x = X, y = Y,
#
# ~\Anaconda3\envs\keras35\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     431             else:
#     432                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 433                                          pickle_kwargs=pickle_kwargs)
#     434         else:
#     435             # Try a pickle
#
# ~\Anaconda3\envs\keras35\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     666         if isfileobj(fp):
#     667             # We can use the fast fromfile() function.
# --> 668             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     669         else:
#     670             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %% [markdown]
# # 載入save_best_model

# %%
import numpy as np
from keras.optimizers import Adam
import keras
import functools

# %%
with CustomObjectScope({'relu6': keras.applications.mobilenet.relu6,'DepthwiseConv2D': keras.applications.mobilenet.DepthwiseConv2D}):
    net_final = load_model('C:/Users/cloudadavncenew0709/Desktop/MobileNet_Adafactor_SaveBest_02.h5')

# %%
for layer in net_final.layers:
    layer.trainable = True

# %%
top3_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=3)

top3_acc.__name__ = 'top3_acc'

net_final.compile(optimizer = optimizerAdafactor, loss='categorical_crossentropy', metrics = ['accuracy', top3_acc])

# %%
for i in range(2):
    X = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/imgonehot_"+str((i+1)*1000)+".npy" )
    Y = np.load( "C:/Users/cloudadavncenew0709/Desktop/numpydataKeras/labelonehot_"+str((i+1)*1000)+".npy" )
    net_final.fit(x = X, y = Y,
                  epochs = 1,
                  validation_data=(V1, V2),
                  verbose = 1)
