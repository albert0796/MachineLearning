# %%
'''import module'''

# basic tool
import os
from functools import reduce
import random

# data process and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# style and text
from matplotlib.font_manager import FontProperties

# fit model and evaluation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesClassifier, ExtraTreesRegressor
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %%
# working dir
working_path = r"D:\mypython_d\Cathay_Big_data_competition_2019"
os.chdir(working_path)

# %%
# use big5 to encoding
train_adj = pd.read_csv("train_cleaned_version1_proc_tree.csv", encoding="Big5", low_memory=False, index_col=0)

# %%
train_original = pd.read_csv("train.csv", encoding="Big5", low_memory=False, index_col=0)

# %%
test_adj = pd.read_csv("test_cleaned_version1_proc_tree.csv", encoding="Big5", low_memory=False, index_col=0)

# %%
test_original = pd.read_csv("test.csv", encoding="Big5", low_memory=False, index_col=0)

# %% [markdown]
# # 處理

# %% [markdown]
# # 1. AMT系列採用中位數補值(不加總)

# %%
amt_list = ["DIEBENEFIT_AMT", "DIEACCIDENT_AMT", "POLICY_VALUE_AMT", "ANNUITY_AMT", 
            "EXPIRATION_AMT", "ACCIDENT_HOSPITAL_REC_AMT", "DISEASES_HOSPITAL_REC_AMT", 
            "OUTPATIENT_SURGERY_AMT", "INPATIENT_SURGERY_AMT", "ILL_ACCELERATION_AMT", 
            "FIRST_CANCER_AMT", "ILL_ADDITIONAL_AMT", "LONG_TERM_CARE_AMT", 
            "MONTHLY_CARE_AMT", "PAY_LIMIT_MED_MISC_AMT"]

# %%
for i in amt_list:
    train_original[i].fillna(train_original[i].describe()["50%"], inplace=True)

# %%
for i in amt_list:
    train_adj[i] = train_original.loc[train_adj.index][i]

# %%
train_adj.drop("TOTAL_AMT", axis=1, inplace=True)

# %% [markdown]
# test

# %%
for i in amt_list:
    test_original[i].fillna(test_original[i].describe()["50%"], inplace=True)

# %%
for i in amt_list:
    test_adj[i] = test_original.loc[test_adj.index][i]

# %%
test_adj.drop("TOTAL_AMT", axis=1, inplace=True)

# %% [markdown]
# # 2.Feature Engineering: AGE & IF_2ND_GEN_IND(是否為保戶二代(Y/N)):
# (1) lowage_is2nd:低年齡者，且是保戶二代(傾向不買重疾險):收入低 + 父母可能幫忙買的作用
#
# (2) midage_isnot2nd:中年齡者，且不是保戶二代(傾向購買重疾險)
#
# (3) mihage_is2nd:中高年齡者，且是保戶二代(傾向購買重疾險)
#
# 把AGE & IF_2ND_GEN_IND drop掉
#
# 以上幾種類別在數量上皆達一定數量。以上所使用欄位皆無NaN。

# %%
train_adj["AGE"].value_counts()
# Out:
# 1    27193
# 2    27090
# 4    23820
# 3    21655
# Name: AGE, dtype: int64

# %%
def lowage_is2nd_engineering(cols):
    
    AGE = cols[0]
    IF_2ND_GEN_IND = cols[1]
    
    if AGE == 1 and IF_2ND_GEN_IND == 1:
        return 1
    else:
        return 0

def midage_isnot2nd_engineering(cols):
    
    AGE = cols[0]
    IF_2ND_GEN_IND = cols[1]
    
    if AGE == 2 and IF_2ND_GEN_IND == 0:
        return 1
    else:
        return 0
    
def mihage_is2nd_engineering(cols):
    
    AGE = cols[0]
    IF_2ND_GEN_IND = cols[1]
    
    if AGE == 3 and IF_2ND_GEN_IND == 1:
        return 1
    else:
        return 0

# %%
train_adj["lowage_is2nd"] = train_adj[["AGE", "IF_2ND_GEN_IND"]].apply(lowage_is2nd_engineering, axis=1)
train_adj["midage_isnot2nd"] = train_adj[["AGE", "IF_2ND_GEN_IND"]].apply(midage_isnot2nd_engineering, axis=1)
train_adj["mihage_is2nd"] = train_adj[["AGE", "IF_2ND_GEN_IND"]].apply(mihage_is2nd_engineering, axis=1)

# %%
train_adj.drop(["AGE", "IF_2ND_GEN_IND"], axis=1, inplace=True)

# %% [markdown]
# test

# %%
test_adj["lowage_is2nd"] = test_adj[["AGE", "IF_2ND_GEN_IND"]].apply(lowage_is2nd_engineering, axis=1)
test_adj["midage_isnot2nd"] = test_adj[["AGE", "IF_2ND_GEN_IND"]].apply(midage_isnot2nd_engineering, axis=1)
test_adj["mihage_is2nd"] = test_adj[["AGE", "IF_2ND_GEN_IND"]].apply(mihage_is2nd_engineering, axis=1)

# %%
test_adj.drop(["AGE", "IF_2ND_GEN_IND"], axis=1, inplace=True)

# %%
train_adj.info(max_cols=150)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99758 entries, 3418 to 2512737
# Data columns (total 116 columns):
# GENDER                       99758 non-null float64
# CHARGE_CITY_CD               99758 non-null int64
# CONTACT_CITY_CD              99758 non-null int64
# EDUCATION_CD                 99758 non-null float64
# MARRIAGE_CD                  99758 non-null float64
# LAST_A_CCONTACT_DT           99758 non-null int64
# L1YR_A_ISSUE_CNT             99758 non-null int64
# LAST_A_ISSUE_DT              99758 non-null int64
# L1YR_B_ISSUE_CNT             99758 non-null int64
# LAST_B_ISSUE_DT              99758 non-null int64
# CHANNEL_A_POL_CNT            99758 non-null int64
# CHANNEL_B_POL_CNT            99758 non-null int64
# OCCUPATION_CLASS_CD          99758 non-null float64
# APC_CNT                      99758 non-null int64
# INSD_CNT                     99758 non-null int64
# APC_1ST_AGE                  99758 non-null float64
# INSD_1ST_AGE                 99758 non-null float64
# APC_1ST_YEARDIF              99758 non-null int64
# RFM_R                        99758 non-null float64
# REBUY_TIMES_CNT              99758 non-null float64
# LEVEL                        99758 non-null float64
# RFM_M_LEVEL                  99758 non-null float64
# LIFE_CNT                     99758 non-null int64
# IF_ISSUE_A_IND               99758 non-null int64
# IF_ISSUE_B_IND               99758 non-null int64
# IF_ISSUE_C_IND               99758 non-null int64
# IF_ISSUE_D_IND               99758 non-null int64
# IF_ISSUE_E_IND               99758 non-null int64
# IF_ISSUE_F_IND               99758 non-null int64
# IF_ISSUE_G_IND               99758 non-null int64
# IF_ISSUE_H_IND               99758 non-null int64
# IF_ISSUE_I_IND               99758 non-null int64
# IF_ISSUE_J_IND               99758 non-null int64
# IF_ISSUE_K_IND               99758 non-null int64
# IF_ISSUE_L_IND               99758 non-null int64
# IF_ISSUE_M_IND               99758 non-null int64
# IF_ISSUE_N_IND               99758 non-null int64
# IF_ISSUE_O_IND               99758 non-null int64
# IF_ISSUE_P_IND               99758 non-null int64
# IF_ISSUE_Q_IND               99758 non-null int64
# IF_ADD_F_IND                 99758 non-null int64
# IF_ADD_L_IND                 99758 non-null int64
# IF_ADD_Q_IND                 99758 non-null int64
# IF_ADD_G_IND                 99758 non-null int64
# IF_ADD_R_IND                 99758 non-null int64
# IF_ADD_IND                   99758 non-null int64
# AG_CNT                       99758 non-null int64
# AG_NOW_CNT                   99758 non-null int64
# CLC_CUR_NUM                  99758 non-null int64
# ANNUAL_INCOME_AMT            99758 non-null float64
# L1YR_PAYMENT_REMINDER_IND    99758 non-null int64
# L1YR_LAPSE_IND               99758 non-null int64
# LAST_B_CONTACT_DT            99758 non-null int64
# LAST_C_DT                    99758 non-null int64
# L1YR_C_CNT                   99758 non-null float64
# BANK_NUMBER_CNT              99758 non-null float64
# INSD_LAST_YEARDIF_CNT        99758 non-null float64
# BMI                          99758 non-null int64
# IF_S_REAL_IND                99758 non-null int64
# IF_Y_REAL_IND                99758 non-null int64
# IM_CNT                       99758 non-null int64
# IM_IS_A_IND                  99758 non-null int64
# IM_IS_B_IND                  99758 non-null int64
# IM_IS_C_IND                  99758 non-null int64
# IM_IS_D_IND                  99758 non-null int64
# TERMINATION_RATE             99758 non-null int64
# X_A_IND                      99758 non-null float64
# X_B_IND                      99758 non-null float64
# X_C_IND                      99758 non-null float64
# X_D_IND                      99758 non-null float64
# X_E_IND                      99758 non-null float64
# X_F_IND                      99758 non-null float64
# X_G_IND                      99758 non-null float64
# X_H_IND                      99758 non-null float64
# TOOL_VISIT_1YEAR_CNT         99758 non-null int64
# IF_HOUSEHOLD_CLAIM_IND       99758 non-null int64
# LIFE_INSD_CNT                99758 non-null float64
# IF_ISSUE_INSD_A_IND          99758 non-null float64
# IF_ISSUE_INSD_B_IND          99758 non-null float64
# IF_ISSUE_INSD_C_IND          99758 non-null float64
# IF_ISSUE_INSD_D_IND          99758 non-null float64
# IF_ISSUE_INSD_E_IND          99758 non-null float64
# IF_ISSUE_INSD_F_IND          99758 non-null float64
# IF_ISSUE_INSD_G_IND          99758 non-null float64
# IF_ISSUE_INSD_H_IND          99758 non-null float64
# IF_ISSUE_INSD_I_IND          99758 non-null float64
# IF_ISSUE_INSD_J_IND          99758 non-null float64
# IF_ISSUE_INSD_K_IND          99758 non-null float64
# IF_ISSUE_INSD_L_IND          99758 non-null float64
# IF_ISSUE_INSD_M_IND          99758 non-null float64
# IF_ISSUE_INSD_N_IND          99758 non-null float64
# IF_ISSUE_INSD_O_IND          99758 non-null float64
# IF_ISSUE_INSD_P_IND          99758 non-null float64
# IF_ISSUE_INSD_Q_IND          99758 non-null float64
# IF_ADD_INSD_IND              99758 non-null float64
# L1YR_GROSS_PRE_AMT           99758 non-null float64
# CUST_9_SEGMENTS_CD           99758 non-null int64
# Y1                           99758 non-null int64
# DIEBENEFIT_AMT               99758 non-null float64
# DIEACCIDENT_AMT              99758 non-null float64
# POLICY_VALUE_AMT             99758 non-null float64
# ANNUITY_AMT                  99758 non-null float64
# EXPIRATION_AMT               99758 non-null float64
# ACCIDENT_HOSPITAL_REC_AMT    99758 non-null float64
# DISEASES_HOSPITAL_REC_AMT    99758 non-null float64
# OUTPATIENT_SURGERY_AMT       99758 non-null float64
# INPATIENT_SURGERY_AMT        99758 non-null float64
# ILL_ACCELERATION_AMT         99758 non-null float64
# FIRST_CANCER_AMT             99758 non-null float64
# ILL_ADDITIONAL_AMT           99758 non-null float64
# LONG_TERM_CARE_AMT           99758 non-null float64
# MONTHLY_CARE_AMT             99758 non-null float64
# PAY_LIMIT_MED_MISC_AMT       99758 non-null float64
# lowage_is2nd                 99758 non-null int64
# midage_isnot2nd              99758 non-null int64
# mihage_is2nd                 99758 non-null int64
# dtypes: float64(57), int64(59)
# memory usage: 89.0 MB

# %%
test_adj.info(max_cols=150)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 1193 to 2558094
# Data columns (total 115 columns):
# GENDER                       150000 non-null float64
# CHARGE_CITY_CD               150000 non-null int64
# CONTACT_CITY_CD              150000 non-null int64
# EDUCATION_CD                 150000 non-null float64
# MARRIAGE_CD                  150000 non-null float64
# LAST_A_CCONTACT_DT           150000 non-null int64
# L1YR_A_ISSUE_CNT             150000 non-null int64
# LAST_A_ISSUE_DT              150000 non-null int64
# L1YR_B_ISSUE_CNT             150000 non-null int64
# LAST_B_ISSUE_DT              150000 non-null int64
# CHANNEL_A_POL_CNT            150000 non-null int64
# CHANNEL_B_POL_CNT            150000 non-null int64
# OCCUPATION_CLASS_CD          150000 non-null float64
# APC_CNT                      150000 non-null int64
# INSD_CNT                     150000 non-null int64
# APC_1ST_AGE                  150000 non-null float64
# INSD_1ST_AGE                 150000 non-null float64
# APC_1ST_YEARDIF              150000 non-null int64
# RFM_R                        150000 non-null float64
# REBUY_TIMES_CNT              150000 non-null float64
# LEVEL                        150000 non-null float64
# RFM_M_LEVEL                  150000 non-null float64
# LIFE_CNT                     150000 non-null int64
# IF_ISSUE_A_IND               150000 non-null int64
# IF_ISSUE_B_IND               150000 non-null int64
# IF_ISSUE_C_IND               150000 non-null int64
# IF_ISSUE_D_IND               150000 non-null int64
# IF_ISSUE_E_IND               150000 non-null int64
# IF_ISSUE_F_IND               150000 non-null int64
# IF_ISSUE_G_IND               150000 non-null int64
# IF_ISSUE_H_IND               150000 non-null int64
# IF_ISSUE_I_IND               150000 non-null int64
# IF_ISSUE_J_IND               150000 non-null int64
# IF_ISSUE_K_IND               150000 non-null int64
# IF_ISSUE_L_IND               150000 non-null int64
# IF_ISSUE_M_IND               150000 non-null int64
# IF_ISSUE_N_IND               150000 non-null int64
# IF_ISSUE_O_IND               150000 non-null int64
# IF_ISSUE_P_IND               150000 non-null int64
# IF_ISSUE_Q_IND               150000 non-null int64
# IF_ADD_F_IND                 150000 non-null int64
# IF_ADD_L_IND                 150000 non-null int64
# IF_ADD_Q_IND                 150000 non-null int64
# IF_ADD_G_IND                 150000 non-null int64
# IF_ADD_R_IND                 150000 non-null int64
# IF_ADD_IND                   150000 non-null int64
# AG_CNT                       150000 non-null int64
# AG_NOW_CNT                   150000 non-null int64
# CLC_CUR_NUM                  150000 non-null int64
# ANNUAL_INCOME_AMT            150000 non-null float64
# L1YR_PAYMENT_REMINDER_IND    150000 non-null int64
# L1YR_LAPSE_IND               150000 non-null int64
# LAST_B_CONTACT_DT            150000 non-null int64
# LAST_C_DT                    150000 non-null int64
# L1YR_C_CNT                   150000 non-null float64
# BANK_NUMBER_CNT              150000 non-null float64
# INSD_LAST_YEARDIF_CNT        150000 non-null float64
# BMI                          150000 non-null int64
# IF_S_REAL_IND                150000 non-null int64
# IF_Y_REAL_IND                150000 non-null int64
# IM_CNT                       150000 non-null int64
# IM_IS_A_IND                  150000 non-null int64
# IM_IS_B_IND                  150000 non-null int64
# IM_IS_C_IND                  150000 non-null int64
# IM_IS_D_IND                  150000 non-null int64
# TERMINATION_RATE             150000 non-null int64
# X_A_IND                      150000 non-null float64
# X_B_IND                      150000 non-null float64
# X_C_IND                      150000 non-null float64
# X_D_IND                      150000 non-null float64
# X_E_IND                      150000 non-null float64
# X_F_IND                      150000 non-null float64
# X_G_IND                      150000 non-null float64
# X_H_IND                      150000 non-null float64
# TOOL_VISIT_1YEAR_CNT         150000 non-null int64
# IF_HOUSEHOLD_CLAIM_IND       150000 non-null int64
# LIFE_INSD_CNT                150000 non-null float64
# IF_ISSUE_INSD_A_IND          150000 non-null float64
# IF_ISSUE_INSD_B_IND          150000 non-null float64
# IF_ISSUE_INSD_C_IND          150000 non-null float64
# IF_ISSUE_INSD_D_IND          150000 non-null float64
# IF_ISSUE_INSD_E_IND          150000 non-null float64
# IF_ISSUE_INSD_F_IND          150000 non-null float64
# IF_ISSUE_INSD_G_IND          150000 non-null float64
# IF_ISSUE_INSD_H_IND          150000 non-null float64
# IF_ISSUE_INSD_I_IND          150000 non-null float64
# IF_ISSUE_INSD_J_IND          150000 non-null float64
# IF_ISSUE_INSD_K_IND          150000 non-null float64
# IF_ISSUE_INSD_L_IND          150000 non-null float64
# IF_ISSUE_INSD_M_IND          150000 non-null float64
# IF_ISSUE_INSD_N_IND          150000 non-null float64
# IF_ISSUE_INSD_O_IND          150000 non-null float64
# IF_ISSUE_INSD_P_IND          150000 non-null float64
# IF_ISSUE_INSD_Q_IND          150000 non-null float64
# IF_ADD_INSD_IND              150000 non-null float64
# L1YR_GROSS_PRE_AMT           150000 non-null float64
# CUST_9_SEGMENTS_CD           150000 non-null int64
# DIEBENEFIT_AMT               150000 non-null float64
# DIEACCIDENT_AMT              150000 non-null float64
# POLICY_VALUE_AMT             150000 non-null float64
# ANNUITY_AMT                  150000 non-null float64
# EXPIRATION_AMT               150000 non-null float64
# ACCIDENT_HOSPITAL_REC_AMT    150000 non-null float64
# DISEASES_HOSPITAL_REC_AMT    150000 non-null float64
# OUTPATIENT_SURGERY_AMT       150000 non-null float64
# INPATIENT_SURGERY_AMT        150000 non-null float64
# ILL_ACCELERATION_AMT         150000 non-null float64
# FIRST_CANCER_AMT             150000 non-null float64
# ILL_ADDITIONAL_AMT           150000 non-null float64
# LONG_TERM_CARE_AMT           150000 non-null float64
# MONTHLY_CARE_AMT             150000 non-null float64
# PAY_LIMIT_MED_MISC_AMT       150000 non-null float64
# lowage_is2nd                 150000 non-null int64
# midage_isnot2nd              150000 non-null int64
# mihage_is2nd                 150000 non-null int64
# dtypes: float64(57), int64(58)
# memory usage: 132.8 MB

# %%
train_adj.to_csv("train_cleaned_version2_proc_tree.csv")
test_adj.to_csv("test_cleaned_version2_proc_tree.csv")

# %% [markdown]
# # One hot encoding

# %%
A = pd.get_dummies(train_adj["CHARGE_CITY_CD"], drop_first=True)
B = pd.get_dummies(train_adj["CONTACT_CITY_CD"], drop_first=True)
C = pd.get_dummies(train_adj["MARRIAGE_CD"], drop_first=True)
D = pd.get_dummies(train_adj["CUST_9_SEGMENTS_CD"], drop_first=True)
E = pd.get_dummies(train_adj["APC_1ST_AGE"], drop_first=True)
F = pd.get_dummies(train_adj["REBUY_TIMES_CNT"], drop_first=True)
G = pd.get_dummies(train_adj["RFM_M_LEVEL"], drop_first=True)
H = pd.get_dummies(train_adj["APC_1ST_YEARDIF"], drop_first=True)
I = pd.get_dummies(train_adj["TERMINATION_RATE"], drop_first=True)
J = pd.get_dummies(train_adj["RFM_R"], drop_first=True)
K = pd.get_dummies(train_adj["LEVEL"], drop_first=True)

# %%
train_adj_encoding = pd.concat([train_adj, A, B, C, D, E, F, G, H, I, J, K], axis=1)

# %%
train_adj_encoding = train_adj_encoding.drop(["CHARGE_CITY_CD", "CONTACT_CITY_CD", "MARRIAGE_CD", 
                      "CUST_9_SEGMENTS_CD", "APC_1ST_AGE", "REBUY_TIMES_CNT", 
                      "RFM_M_LEVEL", "APC_1ST_YEARDIF", "TERMINATION_RATE", "RFM_R", "LEVEL"], axis=1)

# %%
train_adj_encoding.to_csv("train_cleaned_version2_proc_nontree.csv")

# %% [markdown]
# test

# %%
A = pd.get_dummies(test_adj["CHARGE_CITY_CD"], drop_first=True)
B = pd.get_dummies(test_adj["CONTACT_CITY_CD"], drop_first=True)
C = pd.get_dummies(test_adj["MARRIAGE_CD"], drop_first=True)
D = pd.get_dummies(test_adj["CUST_9_SEGMENTS_CD"], drop_first=True)
E = pd.get_dummies(test_adj["APC_1ST_AGE"], drop_first=True)
F = pd.get_dummies(test_adj["REBUY_TIMES_CNT"], drop_first=True)
G = pd.get_dummies(test_adj["RFM_M_LEVEL"], drop_first=True)
H = pd.get_dummies(test_adj["APC_1ST_YEARDIF"], drop_first=True)
I = pd.get_dummies(test_adj["TERMINATION_RATE"], drop_first=True)
J = pd.get_dummies(test_adj["RFM_R"], drop_first=True)
K = pd.get_dummies(test_adj["LEVEL"], drop_first=True)

# %%
test_adj_encoding = pd.concat([test_adj, A, B, C, D, E, F, G, H, I, J, K], axis=1)

# %%
test_adj_encoding = test_adj_encoding.drop(["CHARGE_CITY_CD", "CONTACT_CITY_CD", "MARRIAGE_CD", 
                      "CUST_9_SEGMENTS_CD", "APC_1ST_AGE", "REBUY_TIMES_CNT", 
                      "RFM_M_LEVEL", "APC_1ST_YEARDIF", "TERMINATION_RATE", "RFM_R", "LEVEL"], axis=1)

# %%
test_adj_encoding.to_csv("test_cleaned_version2_proc_nontree.csv")

# %%
train_adj_encoding.info(max_cols=160)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99758 entries, 3418 to 2512737
# Data columns (total 157 columns):
# GENDER                       99758 non-null float64
# EDUCATION_CD                 99758 non-null float64
# LAST_A_CCONTACT_DT           99758 non-null int64
# L1YR_A_ISSUE_CNT             99758 non-null int64
# LAST_A_ISSUE_DT              99758 non-null int64
# L1YR_B_ISSUE_CNT             99758 non-null int64
# LAST_B_ISSUE_DT              99758 non-null int64
# CHANNEL_A_POL_CNT            99758 non-null int64
# CHANNEL_B_POL_CNT            99758 non-null int64
# OCCUPATION_CLASS_CD          99758 non-null float64
# APC_CNT                      99758 non-null int64
# INSD_CNT                     99758 non-null int64
# INSD_1ST_AGE                 99758 non-null float64
# LIFE_CNT                     99758 non-null int64
# IF_ISSUE_A_IND               99758 non-null int64
# IF_ISSUE_B_IND               99758 non-null int64
# IF_ISSUE_C_IND               99758 non-null int64
# IF_ISSUE_D_IND               99758 non-null int64
# IF_ISSUE_E_IND               99758 non-null int64
# IF_ISSUE_F_IND               99758 non-null int64
# IF_ISSUE_G_IND               99758 non-null int64
# IF_ISSUE_H_IND               99758 non-null int64
# IF_ISSUE_I_IND               99758 non-null int64
# IF_ISSUE_J_IND               99758 non-null int64
# IF_ISSUE_K_IND               99758 non-null int64
# IF_ISSUE_L_IND               99758 non-null int64
# IF_ISSUE_M_IND               99758 non-null int64
# IF_ISSUE_N_IND               99758 non-null int64
# IF_ISSUE_O_IND               99758 non-null int64
# IF_ISSUE_P_IND               99758 non-null int64
# IF_ISSUE_Q_IND               99758 non-null int64
# IF_ADD_F_IND                 99758 non-null int64
# IF_ADD_L_IND                 99758 non-null int64
# IF_ADD_Q_IND                 99758 non-null int64
# IF_ADD_G_IND                 99758 non-null int64
# IF_ADD_R_IND                 99758 non-null int64
# IF_ADD_IND                   99758 non-null int64
# AG_CNT                       99758 non-null int64
# AG_NOW_CNT                   99758 non-null int64
# CLC_CUR_NUM                  99758 non-null int64
# ANNUAL_INCOME_AMT            99758 non-null float64
# L1YR_PAYMENT_REMINDER_IND    99758 non-null int64
# L1YR_LAPSE_IND               99758 non-null int64
# LAST_B_CONTACT_DT            99758 non-null int64
# LAST_C_DT                    99758 non-null int64
# L1YR_C_CNT                   99758 non-null float64
# BANK_NUMBER_CNT              99758 non-null float64
# INSD_LAST_YEARDIF_CNT        99758 non-null float64
# BMI                          99758 non-null int64
# IF_S_REAL_IND                99758 non-null int64
# IF_Y_REAL_IND                99758 non-null int64
# IM_CNT                       99758 non-null int64
# IM_IS_A_IND                  99758 non-null int64
# IM_IS_B_IND                  99758 non-null int64
# IM_IS_C_IND                  99758 non-null int64
# IM_IS_D_IND                  99758 non-null int64
# X_A_IND                      99758 non-null float64
# X_B_IND                      99758 non-null float64
# X_C_IND                      99758 non-null float64
# X_D_IND                      99758 non-null float64
# X_E_IND                      99758 non-null float64
# X_F_IND                      99758 non-null float64
# X_G_IND                      99758 non-null float64
# X_H_IND                      99758 non-null float64
# TOOL_VISIT_1YEAR_CNT         99758 non-null int64
# IF_HOUSEHOLD_CLAIM_IND       99758 non-null int64
# LIFE_INSD_CNT                99758 non-null float64
# IF_ISSUE_INSD_A_IND          99758 non-null float64
# IF_ISSUE_INSD_B_IND          99758 non-null float64
# IF_ISSUE_INSD_C_IND          99758 non-null float64
# IF_ISSUE_INSD_D_IND          99758 non-null float64
# IF_ISSUE_INSD_E_IND          99758 non-null float64
# IF_ISSUE_INSD_F_IND          99758 non-null float64
# IF_ISSUE_INSD_G_IND          99758 non-null float64
# IF_ISSUE_INSD_H_IND          99758 non-null float64
# IF_ISSUE_INSD_I_IND          99758 non-null float64
# IF_ISSUE_INSD_J_IND          99758 non-null float64
# IF_ISSUE_INSD_K_IND          99758 non-null float64
# IF_ISSUE_INSD_L_IND          99758 non-null float64
# IF_ISSUE_INSD_M_IND          99758 non-null float64
# IF_ISSUE_INSD_N_IND          99758 non-null float64
# IF_ISSUE_INSD_O_IND          99758 non-null float64
# IF_ISSUE_INSD_P_IND          99758 non-null float64
# IF_ISSUE_INSD_Q_IND          99758 non-null float64
# IF_ADD_INSD_IND              99758 non-null float64
# L1YR_GROSS_PRE_AMT           99758 non-null float64
# Y1                           99758 non-null int64
# DIEBENEFIT_AMT               99758 non-null float64
# DIEACCIDENT_AMT              99758 non-null float64
# POLICY_VALUE_AMT             99758 non-null float64
# ANNUITY_AMT                  99758 non-null float64
# EXPIRATION_AMT               99758 non-null float64
# ACCIDENT_HOSPITAL_REC_AMT    99758 non-null float64
# DISEASES_HOSPITAL_REC_AMT    99758 non-null float64
# OUTPATIENT_SURGERY_AMT       99758 non-null float64
# INPATIENT_SURGERY_AMT        99758 non-null float64
# ILL_ACCELERATION_AMT         99758 non-null float64
# FIRST_CANCER_AMT             99758 non-null float64
# ILL_ADDITIONAL_AMT           99758 non-null float64
# LONG_TERM_CARE_AMT           99758 non-null float64
# MONTHLY_CARE_AMT             99758 non-null float64
# PAY_LIMIT_MED_MISC_AMT       99758 non-null float64
# lowage_is2nd                 99758 non-null int64
# midage_isnot2nd              99758 non-null int64
# mihage_is2nd                 99758 non-null int64
# 2                            99758 non-null uint8
# 3                            99758 non-null uint8
# 4                            99758 non-null uint8
# 5                            99758 non-null uint8
# 6                            99758 non-null uint8
# 7                            99758 non-null uint8
# 8                            99758 non-null uint8
# 2                            99758 non-null uint8
# 3                            99758 non-null uint8
# 4                            99758 non-null uint8
# 5                            99758 non-null uint8
# 6                            99758 non-null uint8
# 7                            99758 non-null uint8
# 8                            99758 non-null uint8
# 1.0                          99758 non-null uint8
# 2.0                          99758 non-null uint8
# 2                            99758 non-null uint8
# 3                            99758 non-null uint8
# 4                            99758 non-null uint8
# 5                            99758 non-null uint8
# 6                            99758 non-null uint8
# 7                            99758 non-null uint8
# 8                            99758 non-null uint8
# 1.0                          99758 non-null uint8
# 2.0                          99758 non-null uint8
# 3.0                          99758 non-null uint8
# 4.0                          99758 non-null uint8
# 1.0                          99758 non-null uint8
# 2.0                          99758 non-null uint8
# 3.0                          99758 non-null uint8
# 4.0                          99758 non-null uint8
# 3.0                          99758 non-null uint8
# 5.0                          99758 non-null uint8
# 7.0                          99758 non-null uint8
# 8.0                          99758 non-null uint8
# 9.0                          99758 non-null uint8
# 10.0                         99758 non-null uint8
# 1                            99758 non-null uint8
# 2                            99758 non-null uint8
# 3                            99758 non-null uint8
# 4                            99758 non-null uint8
# 1                            99758 non-null uint8
# 2                            99758 non-null uint8
# 1.0                          99758 non-null uint8
# 2.0                          99758 non-null uint8
# 3.0                          99758 non-null uint8
# 4.0                          99758 non-null uint8
# 1.0                          99758 non-null uint8
# 2.0                          99758 non-null uint8
# 3.0                          99758 non-null uint8
# 4.0                          99758 non-null uint8
# 5.0                          99758 non-null uint8
# dtypes: float64(51), int64(54), uint8(52)
# memory usage: 85.6 MB

# %%
test_adj_encoding.info(max_cols=160)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 1193 to 2558094
# Data columns (total 156 columns):
# GENDER                       150000 non-null float64
# EDUCATION_CD                 150000 non-null float64
# LAST_A_CCONTACT_DT           150000 non-null int64
# L1YR_A_ISSUE_CNT             150000 non-null int64
# LAST_A_ISSUE_DT              150000 non-null int64
# L1YR_B_ISSUE_CNT             150000 non-null int64
# LAST_B_ISSUE_DT              150000 non-null int64
# CHANNEL_A_POL_CNT            150000 non-null int64
# CHANNEL_B_POL_CNT            150000 non-null int64
# OCCUPATION_CLASS_CD          150000 non-null float64
# APC_CNT                      150000 non-null int64
# INSD_CNT                     150000 non-null int64
# INSD_1ST_AGE                 150000 non-null float64
# LIFE_CNT                     150000 non-null int64
# IF_ISSUE_A_IND               150000 non-null int64
# IF_ISSUE_B_IND               150000 non-null int64
# IF_ISSUE_C_IND               150000 non-null int64
# IF_ISSUE_D_IND               150000 non-null int64
# IF_ISSUE_E_IND               150000 non-null int64
# IF_ISSUE_F_IND               150000 non-null int64
# IF_ISSUE_G_IND               150000 non-null int64
# IF_ISSUE_H_IND               150000 non-null int64
# IF_ISSUE_I_IND               150000 non-null int64
# IF_ISSUE_J_IND               150000 non-null int64
# IF_ISSUE_K_IND               150000 non-null int64
# IF_ISSUE_L_IND               150000 non-null int64
# IF_ISSUE_M_IND               150000 non-null int64
# IF_ISSUE_N_IND               150000 non-null int64
# IF_ISSUE_O_IND               150000 non-null int64
# IF_ISSUE_P_IND               150000 non-null int64
# IF_ISSUE_Q_IND               150000 non-null int64
# IF_ADD_F_IND                 150000 non-null int64
# IF_ADD_L_IND                 150000 non-null int64
# IF_ADD_Q_IND                 150000 non-null int64
# IF_ADD_G_IND                 150000 non-null int64
# IF_ADD_R_IND                 150000 non-null int64
# IF_ADD_IND                   150000 non-null int64
# AG_CNT                       150000 non-null int64
# AG_NOW_CNT                   150000 non-null int64
# CLC_CUR_NUM                  150000 non-null int64
# ANNUAL_INCOME_AMT            150000 non-null float64
# L1YR_PAYMENT_REMINDER_IND    150000 non-null int64
# L1YR_LAPSE_IND               150000 non-null int64
# LAST_B_CONTACT_DT            150000 non-null int64
# LAST_C_DT                    150000 non-null int64
# L1YR_C_CNT                   150000 non-null float64
# BANK_NUMBER_CNT              150000 non-null float64
# INSD_LAST_YEARDIF_CNT        150000 non-null float64
# BMI                          150000 non-null int64
# IF_S_REAL_IND                150000 non-null int64
# IF_Y_REAL_IND                150000 non-null int64
# IM_CNT                       150000 non-null int64
# IM_IS_A_IND                  150000 non-null int64
# IM_IS_B_IND                  150000 non-null int64
# IM_IS_C_IND                  150000 non-null int64
# IM_IS_D_IND                  150000 non-null int64
# X_A_IND                      150000 non-null float64
# X_B_IND                      150000 non-null float64
# X_C_IND                      150000 non-null float64
# X_D_IND                      150000 non-null float64
# X_E_IND                      150000 non-null float64
# X_F_IND                      150000 non-null float64
# X_G_IND                      150000 non-null float64
# X_H_IND                      150000 non-null float64
# TOOL_VISIT_1YEAR_CNT         150000 non-null int64
# IF_HOUSEHOLD_CLAIM_IND       150000 non-null int64
# LIFE_INSD_CNT                150000 non-null float64
# IF_ISSUE_INSD_A_IND          150000 non-null float64
# IF_ISSUE_INSD_B_IND          150000 non-null float64
# IF_ISSUE_INSD_C_IND          150000 non-null float64
# IF_ISSUE_INSD_D_IND          150000 non-null float64
# IF_ISSUE_INSD_E_IND          150000 non-null float64
# IF_ISSUE_INSD_F_IND          150000 non-null float64
# IF_ISSUE_INSD_G_IND          150000 non-null float64
# IF_ISSUE_INSD_H_IND          150000 non-null float64
# IF_ISSUE_INSD_I_IND          150000 non-null float64
# IF_ISSUE_INSD_J_IND          150000 non-null float64
# IF_ISSUE_INSD_K_IND          150000 non-null float64
# IF_ISSUE_INSD_L_IND          150000 non-null float64
# IF_ISSUE_INSD_M_IND          150000 non-null float64
# IF_ISSUE_INSD_N_IND          150000 non-null float64
# IF_ISSUE_INSD_O_IND          150000 non-null float64
# IF_ISSUE_INSD_P_IND          150000 non-null float64
# IF_ISSUE_INSD_Q_IND          150000 non-null float64
# IF_ADD_INSD_IND              150000 non-null float64
# L1YR_GROSS_PRE_AMT           150000 non-null float64
# DIEBENEFIT_AMT               150000 non-null float64
# DIEACCIDENT_AMT              150000 non-null float64
# POLICY_VALUE_AMT             150000 non-null float64
# ANNUITY_AMT                  150000 non-null float64
# EXPIRATION_AMT               150000 non-null float64
# ACCIDENT_HOSPITAL_REC_AMT    150000 non-null float64
# DISEASES_HOSPITAL_REC_AMT    150000 non-null float64
# OUTPATIENT_SURGERY_AMT       150000 non-null float64
# INPATIENT_SURGERY_AMT        150000 non-null float64
# ILL_ACCELERATION_AMT         150000 non-null float64
# FIRST_CANCER_AMT             150000 non-null float64
# ILL_ADDITIONAL_AMT           150000 non-null float64
# LONG_TERM_CARE_AMT           150000 non-null float64
# MONTHLY_CARE_AMT             150000 non-null float64
# PAY_LIMIT_MED_MISC_AMT       150000 non-null float64
# lowage_is2nd                 150000 non-null int64
# midage_isnot2nd              150000 non-null int64
# mihage_is2nd                 150000 non-null int64
# 2                            150000 non-null uint8
# 3                            150000 non-null uint8
# 4                            150000 non-null uint8
# 5                            150000 non-null uint8
# 6                            150000 non-null uint8
# 7                            150000 non-null uint8
# 8                            150000 non-null uint8
# 2                            150000 non-null uint8
# 3                            150000 non-null uint8
# 4                            150000 non-null uint8
# 5                            150000 non-null uint8
# 6                            150000 non-null uint8
# 7                            150000 non-null uint8
# 8                            150000 non-null uint8
# 1.0                          150000 non-null uint8
# 2.0                          150000 non-null uint8
# 2                            150000 non-null uint8
# 3                            150000 non-null uint8
# 4                            150000 non-null uint8
# 5                            150000 non-null uint8
# 6                            150000 non-null uint8
# 7                            150000 non-null uint8
# 8                            150000 non-null uint8
# 1.0                          150000 non-null uint8
# 2.0                          150000 non-null uint8
# 3.0                          150000 non-null uint8
# 4.0                          150000 non-null uint8
# 1.0                          150000 non-null uint8
# 2.0                          150000 non-null uint8
# 3.0                          150000 non-null uint8
# 4.0                          150000 non-null uint8
# 3.0                          150000 non-null uint8
# 5.0                          150000 non-null uint8
# 7.0                          150000 non-null uint8
# 8.0                          150000 non-null uint8
# 9.0                          150000 non-null uint8
# 10.0                         150000 non-null uint8
# 1                            150000 non-null uint8
# 2                            150000 non-null uint8
# 3                            150000 non-null uint8
# 4                            150000 non-null uint8
# 1                            150000 non-null uint8
# 2                            150000 non-null uint8
# 1.0                          150000 non-null uint8
# 2.0                          150000 non-null uint8
# 3.0                          150000 non-null uint8
# 4.0                          150000 non-null uint8
# 1.0                          150000 non-null uint8
# 2.0                          150000 non-null uint8
# 3.0                          150000 non-null uint8
# 4.0                          150000 non-null uint8
# 5.0                          150000 non-null uint8
# dtypes: float64(51), int64(53), uint8(52)
# memory usage: 127.6 MB
